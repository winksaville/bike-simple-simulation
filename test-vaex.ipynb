# %%
import vaex
df = vaex.example()

df
# Out:
# ...
# #        E                FeH                  L                   Lz                   random_index    vx           vy           vz           x             y             z
# 0        -121238.171875   -2.309227609164518   831.0799560546875   -336.426513671875    1511648         53.276722    288.386047   -95.2649078  -0.777470767  2.10626292    1.93743467
# 1        -100819.9140625  -1.788735491591229   1435.1839599609375  -828.7567749023438   2728665         252.810791   -69.9498444  -56.3121033  3.77427316    2.23387194    3.76209331
# 2        -100559.9609375  -0.7618109022478798  1039.2989501953125  920.802490234375     1202632         96.276474    226.440201   -34.7527161  1.3757627     -6.3283844    2.63250017
# 3        -70174.8515625   -1.5208778422936413  2441.724853515625   1183.5899658203125   1020502         204.968842   -205.679016  -58.9777031  -7.06737804   1.31737781    -6.10543537
# ...

# %%
df_negative = df[df.x < 0]

# %%
df_negative[:5][['x', 'y']]
# Out:
#   #           x         y
#   0   -0.777471   2.10626
#   1   -7.06738    1.31738
#   2   -5.17174    7.82915
#   3  -15.9539     5.77126
#   4  -12.3995    13.9182

# %%
se = df.x + df.z
se
df['r'] =  se
df.mean(df.r, binby=df.x, shape=32, limits=[-10, 10])
# Out:
# array([-9.67777315, -8.99466731, -8.17042477, -7.57122871, -6.98273954,
#        -6.28362848, -5.70005784, -5.14022306, -4.52820368, -3.96953423,
#        -3.3362477 , -2.7801045 , -2.20162243, -1.57910621, -0.92856689,
#        -0.35964342,  0.30367721,  0.85684123,  1.53564551,  2.1274488 ,
#         2.69235585,  3.37746363,  4.04648274,  4.59580105,  5.20540601,
#         5.73475069,  6.28384101,  6.67880226,  7.46059303,  8.13480148,
#         8.90738265,  9.6117928 ])

# %%
df.mean(df.r, binby=[df.x, df.y], shape=32, limits=[-10, 10])
# Out:
# array([[-11.62082062,  -8.46273879, -10.60792393, ..., -12.03216726,
#         -12.36418447,  -8.61562036],
#        [ -6.75151381,  -7.90369175,  -8.79522246, ..., -10.74027312,
#          -8.4502931 ,  -9.6721129 ],
#        [ -8.06167812,  -9.37508708,  -8.40348457, ...,  -8.11148423,
#          -9.01893255,  -8.92884817],
#        ...,
#        [  7.27869824,   8.7242469 ,   8.47423951, ...,   6.98420752,
#           8.69661853,   8.24185806],
#        [  7.5084596 ,   8.87245034,   8.60179587, ...,  10.58042476,
#           9.11809514,  11.61155883],
#        [  9.2796653 ,  12.32155351,  10.4433037 , ...,   8.58668562,
#          10.6476066 ,   8.24133482]])

# %%
df.count(df.r, binby=[df.x, df.y], shape=32, limits=[-10, 10])
# Out:
# array([[22, 33, 37, ..., 58, 38, 45],
#        [37, 36, 47, ..., 52, 36, 53],
#        [34, 42, 47, ..., 59, 44, 56],
#        ...,
#        [73, 73, 84, ..., 41, 40, 37],
#        [53, 58, 63, ..., 34, 35, 28],
#        [51, 32, 46, ..., 47, 33, 36]])

# %%
df.plot(df.x, df.y, show=True)
